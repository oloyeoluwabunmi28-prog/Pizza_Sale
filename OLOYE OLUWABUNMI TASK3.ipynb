# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
order_detail = pd.read_csv("/content/order_details.csv")

order_detail
# Out:
#        order_details_id  order_id       pizza_id  quantity
# 0                     1         1     hawaiian_m         1
# 1                     2         2  classic_dlx_m         1
# 2                     3         2  five_cheese_l         1
# 3                     4         2    ital_supr_l         1
# 4                     5         2     mexicana_m         1
# ...                 ...       ...            ...       ...
# 48615             48616     21348  ckn_alfredo_m         1
# 48616             48617     21348  four_cheese_l         1
# 48617             48618     21348   napolitana_s         1
# 48618             48619     21349     mexicana_l         1
# 48619             48620     21350      bbq_ckn_s         1
#
# [48620 rows x 4 columns]

# %%
orders = pd.read_csv("/content/orders.csv")

orders
# Out:
#        order_id        date      time
# 0             1  2015-01-01  11:38:36
# 1             2  2015-01-01  11:57:40
# 2             3  2015-01-01  12:12:28
# 3             4  2015-01-01  12:16:31
# 4             5  2015-01-01  12:21:30
# ...         ...         ...       ...
# 21345     21346  2015-12-31  20:51:07
# 21346     21347  2015-12-31  21:14:37
# 21347     21348  2015-12-31  21:23:10
# 21348     21349  2015-12-31  22:09:54
# 21349     21350  2015-12-31  23:02:05
#
# [21350 rows x 3 columns]

# %%
pizza_type = pd.read_csv("/content/pizza_types.csv", encoding="latin1")


pizza_type
# Out:
#    pizza_type_id                                        name category  \
# 0        bbq_ckn                  The Barbecue Chicken Pizza  Chicken
# 1       cali_ckn                The California Chicken Pizza  Chicken
# 2    ckn_alfredo                   The Chicken Alfredo Pizza  Chicken
# 3      ckn_pesto                     The Chicken Pesto Pizza  Chicken
# 4     southw_ckn                 The Southwest Chicken Pizza  Chicken
# 5       thai_ckn                      The Thai Chicken Pizza  Chicken
# 6       big_meat                          The Big Meat Pizza  Classic
# 7    classic_dlx                    The Classic Deluxe Pizza  Classic
# 8       hawaiian                          The Hawaiian Pizza  Classic
# 9    ital_cpcllo                 The Italian Capocollo Pizza  Classic
# 10    napolitana                        The Napolitana Pizza  Classic
# 11   pep_msh_pep  The Pepperoni, Mushroom, and Peppers Pizza  Classic
# ...

# %%
pizzas = pd.read_csv("/content/pizzas.csv")


pizzas
# Out:
#          pizza_id pizza_type_id size  price
# 0       bbq_ckn_s       bbq_ckn    S  12.75
# 1       bbq_ckn_m       bbq_ckn    M  16.75
# 2       bbq_ckn_l       bbq_ckn    L  20.75
# 3      cali_ckn_s      cali_ckn    S  12.75
# 4      cali_ckn_m      cali_ckn    M  16.75
# ..            ...           ...  ...    ...
# 91  spinach_fet_m   spinach_fet    M  16.00
# 92  spinach_fet_l   spinach_fet    L  20.25
# 93   veggie_veg_s    veggie_veg    S  12.00
# 94   veggie_veg_m    veggie_veg    M  16.00
# 95   veggie_veg_l    veggie_veg    L  20.25
#
# [96 rows x 4 columns]

# %%
dic = pd.read_csv("/content/data_dictionary.csv")

dic
# Out:
#             Table             Field  \
# 0          orders          order_id
# 1          orders              date
# 2          orders              time
# 3   order_details  order_details_id
# 4   order_details          order_id
# 5   order_details          pizza_id
# 6   order_details          quantity
# 7          pizzas          pizza_id
# 8          pizzas     pizza_type_id
# 9          pizzas              size
# 10         pizzas             price
# 11    pizza_types     pizza_type_id
# 12    pizza_types              name
# 13    pizza_types          category
# 14    pizza_types       ingredients
#
#                                           Description
# 0   Unique identifier for each order placed by a t...
# 1   Date the order was placed (entered into the sy...
# 2   Time the order was placed (entered into the sy...
# 3   Unique identifier for each pizza placed within...
# 4   Foreign key that ties the details in each orde...
# ...

# %% [markdown]
# #Merging All the data together

# %%
#Merging order details and order id together.

merge_order= pd.merge(order_detail, orders, on='order_id', how='outer')


merge_order
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                     2         2  classic_dlx_m         1  2015-01-01
# 2                     3         2  five_cheese_l         1  2015-01-01
# 3                     4         2    ital_supr_l         1  2015-01-01
# 4                     5         2     mexicana_m         1  2015-01-01
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  2015-12-31
# 48616             48617     21348  four_cheese_l         1  2015-12-31
# 48617             48618     21348   napolitana_s         1  2015-12-31
# 48618             48619     21349     mexicana_l         1  2015-12-31
# 48619             48620     21350      bbq_ckn_s         1  2015-12-31
#
#            time
# 0      11:38:36
# 1      11:57:40
# 2      11:57:40
# 3      11:57:40
# 4      11:57:40
# ...

# %%
#Merging pizzatype and pizza type id together

merge_pizza= pd.merge(pizza_type,pizzas, on='pizza_type_id', how='outer')


merge_pizza
# Out:
#    pizza_type_id                               name category  \
# 0        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 1        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 2        bbq_ckn         The Barbecue Chicken Pizza  Chicken
# 3       big_meat                 The Big Meat Pizza  Classic
# 4       big_meat                 The Big Meat Pizza  Classic
# ..           ...                                ...      ...
# 91     the_greek                    The Greek Pizza  Classic
# 92     the_greek                    The Greek Pizza  Classic
# 93    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 94    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
# 95    veggie_veg  The Vegetables + Vegetables Pizza   Veggie
#
#                                           ingredients       pizza_id size  \
# 0   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_s    S
# 1   Barbecued Chicken, Red Peppers, Green Peppers,...      bbq_ckn_m    M
# ...

# %%
#Joining the two merged above together

merged_data = pd.merge(merge_order,merge_pizza, on='pizza_id', how='inner')


merged_data
# Out:
#        order_details_id  order_id       pizza_id  quantity        date  \
# 0                     1         1     hawaiian_m         1  2015-01-01
# 1                     2         2  classic_dlx_m         1  2015-01-01
# 2                     3         2  five_cheese_l         1  2015-01-01
# 3                     4         2    ital_supr_l         1  2015-01-01
# 4                     5         2     mexicana_m         1  2015-01-01
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  2015-12-31
# 48616             48617     21348  four_cheese_l         1  2015-12-31
# 48617             48618     21348   napolitana_s         1  2015-12-31
# 48618             48619     21349     mexicana_l         1  2015-12-31
# 48619             48620     21350      bbq_ckn_s         1  2015-12-31
#
#            time pizza_type_id                        name category  \
# ...

# %%
merged_data.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity        date      time  \
# 0                 1         1     hawaiian_m         1  2015-01-01  11:38:36
# 1                 2         2  classic_dlx_m         1  2015-01-01  11:57:40
# 2                 3         2  five_cheese_l         1  2015-01-01  11:57:40
# 3                 4         2    ital_supr_l         1  2015-01-01  11:57:40
# 4                 5         2     mexicana_m         1  2015-01-01  11:57:40
#
#   pizza_type_id                       name category  \
# 0      hawaiian         The Hawaiian Pizza  Classic
# 1   classic_dlx   The Classic Deluxe Pizza  Classic
# 2   five_cheese      The Five Cheese Pizza   Veggie
# 3     ital_supr  The Italian Supreme Pizza  Supreme
# 4      mexicana         The Mexicana Pizza   Veggie
#
#                                          ingredients size  price
# 0           Sliced Ham, Pineapple, Mozzarella Cheese    M  13.25
# ...

# %%
#step1 The total revenue/sales


merged_data["Total sales"] = merged_data["quantity"] * merged_data["price"]

# %%
merged_data.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity        date      time  \
# 0                 1         1     hawaiian_m         1  2015-01-01  11:38:36
# 1                 2         2  classic_dlx_m         1  2015-01-01  11:57:40
# 2                 3         2  five_cheese_l         1  2015-01-01  11:57:40
# 3                 4         2    ital_supr_l         1  2015-01-01  11:57:40
# 4                 5         2     mexicana_m         1  2015-01-01  11:57:40
#
#   pizza_type_id                       name category  \
# 0      hawaiian         The Hawaiian Pizza  Classic
# 1   classic_dlx   The Classic Deluxe Pizza  Classic
# 2   five_cheese      The Five Cheese Pizza   Veggie
# 3     ital_supr  The Italian Supreme Pizza  Supreme
# 4      mexicana         The Mexicana Pizza   Veggie
#
#                                          ingredients size  price  Total sales
# 0           Sliced Ham, Pineapple, Mozzarella Cheese    M  13.25        13.25
# ...

# %%
#Step 2. To find the total quantity sold



total_quantity_sold = merged_data["quantity"].sum()


total_quantity_sold
# Out:
# np.int64(49574)

# %%
#Step 3. To find the total orders



total_orders = len(merged_data) #counts the number of orders

total_orders
# Out:
# 48620

# %%
total_orders =merged_data["order_id"].nunique()  #returns an array of orders id

total_orders
# Out:
# 21350

# %%
#Step4. To find pizza types they sell



pizza_sold_by_type = merged_data.groupby("name")["price"].sum().reset_index()



pizza_sold_by_type
# Out:
#                                           name     price
# 0                   The Barbecue Chicken Pizza  41683.00
# 1                           The Big Meat Pizza  21732.00
# 2                         The Brie Carre Pizza  11352.00
# 3                          The Calabrese Pizza  15763.75
# 4                 The California Chicken Pizza  40166.50
# 5                    The Chicken Alfredo Pizza  16779.00
# 6                      The Chicken Pesto Pizza  16484.75
# 7                     The Classic Deluxe Pizza  37631.50
# 8                        The Five Cheese Pizza  25141.50
# 9                        The Four Cheese Pizza  31361.10
# 10                             The Greek Pizza  28170.10
# 11                      The Green Garden Pizza  13819.50
# 12                          The Hawaiian Pizza  31561.75
# 13                 The Italian Capocollo Pizza  24641.50
# 14                   The Italian Supreme Pizza  32856.25
# ...

# %%
#Step 5. Find the average price of the pizzas



avg_price_by_pizza = merged_data.groupby("name")["price"].mean().reset_index()


avg_price_by_pizza
# Out:
#                                           name      price
# 0                   The Barbecue Chicken Pizza  17.572934
# 1                           The Big Meat Pizza  12.000000
# 2                         The Brie Carre Pizza  23.650000
# 3                          The Calabrese Pizza  17.005124
# 4                 The California Chicken Pizza  17.448523
# 5                    The Chicken Alfredo Pizza  17.121429
# 6                      The Chicken Pesto Pizza  17.153746
# 7                     The Classic Deluxe Pizza  15.575952
# 8                        The Five Cheese Pizza  18.500000
# 9                        The Four Cheese Pizza  16.951946
# 10                             The Greek Pizza  20.035633
# 11                      The Green Garden Pizza  14.001520
# 12                          The Hawaiian Pizza  13.317194
# 13                 The Italian Capocollo Pizza  17.426803
# 14                   The Italian Supreme Pizza  17.769740
# ...

# %%
#Step 6 To find the peak hours of sales


merged_data["hour"] = pd.to_datetime(merged_data["time"]).dt.hour
# Out:
# /tmp/ipython-input-2183813769.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   merged_data["hour"] = pd.to_datetime(merged_data["time"]).dt.hour

# %%
sales_by_peak_hour = merged_data.groupby("hour")["quantity"].sum().reset_index()


sales_by_peak_hour
# Out:
#     hour  quantity
# 0      9         4
# 1     10        18
# 2     11      2728
# 3     12      6776
# 4     13      6413
# 5     14      3613
# 6     15      3216
# 7     16      4239
# 8     17      5211
# 9     18      5417
# 10    19      4406
# 11    20      3534
# 12    21      2545
# 13    22      1386
# 14    23        68

# %%
#Step 7a. To Find the Total sales made on each day of the week


merged_data["date"] = pd.to_datetime(merged_data["date"])

merged_data["days_of_the_week"] = merged_data["date"].dt.day_name()

total_sales_by_day = merged_data.groupby("days_of_the_week")["price"].sum().reset_index()


total_sales_by_day
# Out:
#   days_of_the_week      price
# 0           Friday  133773.90
# 1           Monday  105357.15
# 2         Saturday  120865.30
# 3           Sunday   97264.75
# 4         Thursday  120912.45
# 5          Tuesday  111764.70
# 6        Wednesday  112006.45

# %%
#Visualizing the results

plt.bar(total_sales_by_day["days_of_the_week"], total_sales_by_day["price"])
plt.xticks(rotation=90)
plt.title("Weekly Sales report")
plt.xlabel ("Days of the Week")
plt.ylabel("Total price")


plt.show()

# %%
#Step 7b. To find the day of the week when sales are made most

best_day =total_sales_by_day.loc[total_sales_by_day["price"].idxmax()]

best_day
# Out:
# days_of_the_week      Friday
# price               133773.9
# Name: 0, dtype: object

# %%
#Step 8. Find the top 5 bestselling pizzas


top_best = merged_data.groupby("name")["quantity"].sum().reset_index()


top_best =top_best.sort_values("quantity", ascending=False)


top_best
# Out:
#                                           name  quantity
# 7                     The Classic Deluxe Pizza      2453
# 0                   The Barbecue Chicken Pizza      2432
# 12                          The Hawaiian Pizza      2422
# 20                         The Pepperoni Pizza      2418
# 30                      The Thai Chicken Pizza      2371
# 4                 The California Chicken Pizza      2370
# 23                          The Sicilian Pizza      1938
# 26                     The Spicy Italian Pizza      1924
# 25                 The Southwest Chicken Pizza      1917
# 1                           The Big Meat Pizza      1914
# 9                        The Four Cheese Pizza      1902
# 14                   The Italian Supreme Pizza      1884
# 31           The Vegetables + Vegetables Pizza      1526
# 17                          The Mexicana Pizza      1484
# 18                        The Napolitana Pizza      1464
# ...

# %%
# the top 5 will be


top_best.head()
# Out:
#                           name  quantity
# 7     The Classic Deluxe Pizza      2453
# 0   The Barbecue Chicken Pizza      2432
# 12          The Hawaiian Pizza      2422
# 20         The Pepperoni Pizza      2418
# 30      The Thai Chicken Pizza      2371

# %%
#Step 9 To find the sales made in each month

merged_data["date"]=pd.to_datetime(merged_data["date"])


merged_data["month"]=merged_data["date"].dt.month_name()


sales_by_month = merged_data.groupby("month")["price"].sum().reset_index()


sales_by_month
# Out:
#         month     price
# 0       April  67286.20
# 1      August  67068.80
# 2    December  63450.00
# 3    February  64067.40
# 4     January  68472.70
# 5        July  71027.45
# 6        June  66796.30
# 7       March  69198.00
# 8         May  69939.35
# 9    November  69054.00
# 10    October  62566.50
# 11  September  63018.00

# %%
#another method adding the year


merged_data["month"] =merged_data["date"].dt.month_name()

merged_data["year"] = merged_data["date"].dt.year

sales_by_month_year =merged_data.groupby(["year","month"])["price"].sum().reset_index()


sales_by_month_year
# Out:
#     year      month     price
# 0   2015      April  67286.20
# 1   2015     August  67068.80
# 2   2015   December  63450.00
# 3   2015   February  64067.40
# 4   2015    January  68472.70
# 5   2015       July  71027.45
# 6   2015       June  66796.30
# 7   2015      March  69198.00
# 8   2015        May  69939.35
# 9   2015   November  69054.00
# 10  2015    October  62566.50
# 11  2015  September  63018.00

# %%
plt.plot(sales_by_month["month"], sales_by_month["price"],color="red",marker="o")
plt.title("Pizza Monthly Sales")
plt.xticks(rotation=90)
plt.xlabel("Month of the year")
plt.ylabel("Pizza Price")

plt.show()

# %% [markdown]
# #The plot shows a clear peak of ales during the summer months,especially July  and a slow Sales in October.
#
# #This suggest that  pizza Sales are higher during summer month(July) when people are likely to order food for outdoor gathering and in contrast, slow Sales in September and October when consume are being cautious with their spending before the holiday season/Christmas.

# %%
#Step10. To know if there Pizza type with low sales on the menu

pizza_type_low_sales= merged_data.groupby("name")["quantity"].sum().reset_index()

pizza_type_low_sales =pizza_type_low_sales.sort_values("quantity",ascending =True)

pizza_type_low_sales
# Out:
#                                           name  quantity
# 2                         The Brie Carre Pizza       490
# 16                     The Mediterranean Pizza       934
# 3                          The Calabrese Pizza       937
# 28                   The Spinach Supreme Pizza       950
# 24                       The Soppressata Pizza       961
# 27                     The Spinach Pesto Pizza       970
# 6                      The Chicken Pesto Pizza       973
# 15                The Italian Vegetables Pizza       981
# 5                    The Chicken Alfredo Pizza       987
# 11                      The Green Garden Pizza       997
# 21  The Pepperoni, Mushroom, and Peppers Pizza      1359
# 8                        The Five Cheese Pizza      1409
# 10                             The Greek Pizza      1420
# 13                 The Italian Capocollo Pizza      1438
# 29                  The Spinach and Feta Pizza      1446
# ...

# %%
pizza_type_low_sales.head(5)
# Out:
#                          name  quantity
# 2        The Brie Carre Pizza       490
# 16    The Mediterranean Pizza       934
# 3         The Calabrese Pizza       937
# 28  The Spinach Supreme Pizza       950
# 24      The Soppressata Pizza       961

# %%
#To know pizza that is not doing well/low sale by revenue using pizza type id.

merged_data ["revenue"] = merged_data["quantity"] * merged_data["price"]

pizza_type_revenue = merged_data.groupby("pizza_type_id")["revenue"].sum().reset_index()

pizza_type_revenue =pizza_type_revenue.sort_values("revenue",ascending =True)


low_revenue_pizza = pizza_type_revenue.head(5)

low_revenue_pizza
# Out:
#    pizza_type_id   revenue
# 2     brie_carre  11588.50
# 10  green_garden  13955.75
# 28  spinach_supr  15277.75
# 15  mediterraneo  15360.50
# 26    spin_pesto  15596.00

# %% [markdown]
# #With this two method above, definitely pizza with the name The Brie Carre Pizza is first on the list with low revenue/sales.
